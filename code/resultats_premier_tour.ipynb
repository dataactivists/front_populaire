# %% [markdown]
# # Résultats premier tour

# %%
import json

import altair as alt
import pandas as pd
import requests

# %% [markdown]
# ## Load data

# %%
with open('../data/raw_data/results.json', 'r') as file:
    data = json.load(file)

# %%
list(data.items())[:2]
# Out:
# [('001-01',
#   {'blocs': [{'code': 'EXD',
#      'color': '#030031',
#      'name': 'Ext. droite',
#      'nb': 23819,
#      'pos': 15,
#      'score': 39.37},
#     {'code': 'LR',
#      'color': '#29609a',
#      'name': 'LR',
#      'nb': 14495,
#      'pos': 12,
#      'score': 23.96},
#     {'code': 'NFP',
#      'color': '#bb191c',
#      'name': 'NFP',
#      'nb': 14188,
#      'pos': 3,
#      'score': 23.45},
#     {'code': 'ENS',
#      'color': '#f69b36',
#      'name': 'Ensemble !',
#      'nb': 7063,
#      'pos': 8,
#      'score': 11.68},
#     {'code': 'others',
#      'color': '#e7e9ea',
#      'name': 'Autres',
#      'nb': None,
#      'pos': 99,
#      'score': 1.54}],
#    'rounds': [{'round': 'T1',
#      'linesGroups': [{'code': 'participation',
#        'wording': 'Participation',
#        'lines': [{'code': 'PARTICIP',
#          'level': 'local',
#          'score': 71.2,
#          'nb': 61830,
#          'label': ''}]},
#       {'code': 'qualified',
#        'wording': 'Qualifiés au second tour',
#        'lines': [{'code': 'RN',
#          'sex': 'M.',
#          'score': 39.37,
#          'level': 'local',
#          'label': 'Christophe MAÎTRE / EXD / Rassemblement national',
#          'panel': '2',
#          'withdrawn': False,
#          'nb': 23819,
#          'pole_code': 'EXD',
#          'pole_party': 'Rassemblement national',
#          'party_name': 'Rassemblement national',
#          'incumbent': False,
#          'spread': {'ratio': 15.08, 'nb': 9324}},
#         {'code': 'LR',
#          'sex': 'M.',
#          'score': 23.96,
#          'level': 'local',
#          'label': 'Xavier BRETON / LR / Les Républicains',
#          'panel': '3',
#          'withdrawn': False,
#          'nb': 14495,
#          'pole_code': 'LR',
#          'pole_party': 'Les Républicains',
#          'party_name': 'Les Républicains',
#          'incumbent': True,
#          'spread': {'ratio': 0.5, 'nb': 307}},
#         {'code': 'UG',
#          'sex': 'M.',
#          'score': 23.45,
#          'level': 'local',
#          'label': 'Sébastien GUERAUD / NFP / Parti socialiste',
#          'panel': '4',
#          'withdrawn': False,
#          'nb': 14188,
#          'pole_code': 'NFP',
#          'pole_party': 'Parti socialiste',
#          'party_name': 'Parti socialiste',
#          'incumbent': False,
#          'spread': {'ratio': 11.52, 'nb': 7125}}]},
#       {'code': 'others',
#        'wording': 'Autres candidats',
#        'lines': [{'code': 'ENS',
#          'sex': 'M.',
#          'score': 11.68,
#          'level': 'local',
#          'label': 'Vincent GUILLERMIN / ENS / Renaissance',
#          'panel': '7',
#          'withdrawn': False,
#          'nb': 7063,
#          'pole_code': 'ENS',
#          'pole_party': 'Renaissance',
#          'party_name': 'Renaissance',
#          'incumbent': False,
#          'spread': {'ratio': 10.75, 'nb': 6644}},
#         {'code': 'EXG',
#          'sex': 'M.',
#          'score': 0.69,
#          'level': 'local',
#          'label': 'Éric LAHY / Lutte ouvrière',
#          'panel': '1',
#          'withdrawn': False,
#          'nb': 419,
#          'pole_code': '',
#          'pole_party': '',
#          'party_name': 'Lutte ouvrière',
#          'incumbent': False,
#          'spread': {'ratio': 0.17, 'nb': 105}},
#         {'code': 'DSV',
#          'sex': 'M.',
#          'score': 0.52,
#          'level': 'local',
#          'label': 'Michael MENDES / Debout la France',
#          'panel': '6',
#          'withdrawn': False,
#          'nb': 314,
#          'pole_code': '',
#          'pole_party': '',
#          'party_name': 'Debout la France',
#          'incumbent': False,
#          'spread': {'ratio': 0.19, 'nb': 117}},
#         {'code': 'DSV',
#          'sex': 'M.',
#          'score': 0.33,
#          'level': 'local',
#          'label': 'Cyril VINCENT / Droite souverainiste',
#          'panel': '5',
#          'withdrawn': False,
#          'nb': 197,
#          'pole_code': '',
#          'pole_party': '',
#          'party_name': 'Droite souverainiste',
#          'incumbent': False,
#          'spread': {'ratio': 0.19, 'nb': -1}}]}]}],
#    'code': '001-01',
#    'estimation': False}),
#  ('001-02',
#   {'blocs': [{'code': 'EXD',
#      'color': '#030031',
#      'name': 'Ext. droite',
#      'nb': 28189,
#      'pos': 15,
#      'score': 39.2},
#     {'code': 'ENS',
#      'color': '#f69b36',
#      'name': 'Ensemble !',
#      'nb': 17414,
#      'pos': 8,
#      'score': 24.21},
#     {'code': 'NFP',
#      'color': '#bb191c',
#      'name': 'NFP',
#      'nb': 16981,
#      'pos': 3,
#      'score': 23.61},
#     {'code': 'LR',
#      'color': '#29609a',
#      'name': 'LR',
#      'nb': 6737,
#      'pos': 12,
#      'score': 9.37},
#     {'code': 'others',
#      'color': '#e7e9ea',
#      'name': 'Autres',
#      'nb': None,
#      'pos': 99,
#      'score': 3.61}],
#    'rounds': [{'round': 'T1',
#      'linesGroups': [{'code': 'participation',
#        'wording': 'Participation',
#        'lines': [{'code': 'PARTICIP',
#          'level': 'local',
#          'score': 72.09,
#          'nb': 73436,
#          'label': ''}]},
#       {'code': 'qualified',
#        'wording': 'Qualifiés au second tour',
#        'lines': [{'code': 'RN',
#          'sex': 'M.',
#          'score': 39.2,
#          'level': 'local',
#          'label': 'Andréa KOTARAC / EXD / Rassemblement national',
#          'panel': '1',
#          'withdrawn': False,
#          'nb': 28189,
#          'pole_code': 'EXD',
#          'pole_party': 'Rassemblement national',
#          'party_name': 'Rassemblement national',
#          'incumbent': False,
#          'spread': {'ratio': 14.67, 'nb': 10775}},
#         {'code': 'ENS',
#          'sex': 'M.',
#          'score': 24.21,
#          'level': 'local',
#          'label': 'Romain DAUBIÉ / ENS / Modem',
#          'panel': '2',
#          'withdrawn': False,
#          'nb': 17414,
#          'pole_code': 'ENS',
#          'pole_party': 'Modem',
#          'party_name': 'Modem',
#          'incumbent': True,
#          'spread': {'ratio': 0.59, 'nb': 433}},
#         {'code': 'UG',
#          'sex': 'M.',
#          'score': 23.61,
#          'level': 'local',
#          'label': 'Maxime MEYER / NFP / Les Écologistes',
#          'panel': '5',
#          'withdrawn': False,
#          'nb': 16981,
#          'pole_code': 'NFP',
#          'pole_party': 'Les Écologistes',
#          'party_name': 'Les Écologistes',
#          'incumbent': False,
#          'spread': {'ratio': 13.95, 'nb': 10244}}]},
#       {'code': 'others',
#        'wording': 'Autres candidats',
#        'lines': [{'code': 'LR',
#          'sex': 'M.',
#          'score': 9.37,
#          'level': 'local',
#          'label': 'Alexandre NANCHI / LR / Les Républicains',
#          'panel': '6',
#          'withdrawn': False,
#          'nb': 6737,
#          'pole_code': 'LR',
#          'pole_party': 'Les Républicains',
#          'party_name': 'Les Républicains',
#          'incumbent': False,
#          'spread': {'ratio': 6.64, 'nb': 4874}},
#         {'code': 'EXD',
#          'sex': 'M.',
#          'score': 2.59,
#          'level': 'local',
#          'label': 'Olivier EYRAUD / Union des droites',
#          'panel': '3',
#          'withdrawn': False,
#          'nb': 1863,
#          'pole_code': '',
#          'pole_party': '',
#          'party_name': 'Union des droites',
#          'incumbent': False,
#          'spread': {'ratio': 1.54, 'nb': 1129}},
#         {'code': 'EXG',
#          'sex': 'M.',
#          'score': 1.02,
#          'level': 'local',
#          'label': 'Vincent GOUTAGNY / Lutte ouvrière',
#          'panel': '4',
#          'withdrawn': False,
#          'nb': 734,
#          'pole_code': '',
#          'pole_party': '',
#          'party_name': 'Lutte ouvrière',
#          'incumbent': False,
#          'spread': {'ratio': 1.54, 'nb': -1}}]}]}],
#    'code': '001-02',
#    'estimation': False})]

# %%
df = pd.DataFrame.from_dict(data, orient='index').reset_index()

df.head()
# Out:
#     index                                              blocs  \
# 0  001-01  [{'code': 'EXD', 'color': '#030031', 'name': '...
# 1  001-02  [{'code': 'EXD', 'color': '#030031', 'name': '...
# 2  001-03  [{'code': 'ENS', 'color': '#f69b36', 'name': '...
# 3  001-04  [{'code': 'EXD', 'color': '#030031', 'name': '...
# 4  001-05  [{'code': 'EXD', 'color': '#030031', 'name': '...
#
#                                               rounds    code  estimation
# 0  [{'round': 'T1', 'linesGroups': [{'code': 'par...  001-01       False
# 1  [{'round': 'T1', 'linesGroups': [{'code': 'par...  001-02       False
# 2  [{'round': 'T1', 'linesGroups': [{'code': 'par...  001-03       False
# 3  [{'round': 'T1', 'linesGroups': [{'code': 'par...  001-04       False
# 4  [{'round': 'T1', 'linesGroups': [{'code': 'par...  001-05       False

# %% [markdown]
# ## Clean data

# %%
df.describe()
# Out:
#          index                                              blocs  \
# count      577                                                577
# unique     577                                                575
# top     001-01  [{'code': 'others', 'color': '#e7e9ea', 'name'...
# freq         1                                                  3
#
#                                                    rounds    code estimation
# count                                                 577     577        577
# unique                                                577     577          1
# top     [{'round': 'T1', 'linesGroups': [{'code': 'par...  001-01      False
# freq                                                    1       1        577

# %%
# dropper les colonnes inutiles
df = df.drop(columns=['blocs', 'code', 'estimation'])

# %%
# renommer les colonnes
df.columns = ['code_circo', 'premier_tour']

# %%
# extraire les infos utiles sur le premier tour
df['premier_tour'] = df['premier_tour'].apply(lambda x: x[0]['linesGroups'])

# %%
# vérifier que le premier élément est toujours 'participation'
set(j[0]['code'] for i, j in df['premier_tour'].items())
# Out:
# {'participation'}

# %%
# vérifier que 'participation' a seulement 1 element
set(len(j[0]['lines']) for i, j in df['premier_tour'].items())
# Out:
# {1}

# %%
# exemple de données de 'participation'
df['premier_tour'][0][0]['lines'][0]
# Out:
# {'code': 'PARTICIP', 'level': 'local', 'score': 71.2, 'nb': 61830, 'label': ''}

# %%
# populer colonne 'participation'
df['participation'] = df['premier_tour'].apply(lambda x: x[0]['lines'][0]['score'])

# %%
df['participation']
# Out:
# 0      71.20
# 1      72.09
# 2      65.33
# 3      70.31
# 4      68.00
#        ...
# 572    44.76
# 573    22.20
# 574    28.07
# 575    32.06
# 576    40.81
# Name: participation, Length: 577, dtype: float64

# %%
# exemple de données 'qualified'
df['premier_tour'][4][1:]
# Out:
# [{'code': 'qualified',
#   'wording': 'Qualifiés au second tour',
#   'lines': [{'code': 'UXD',
#     'sex': 'M.',
#     'score': 39.12,
#     'level': 'local',
#     'label': 'Marc CHAVENT / EXD / À droite ! Les amis d’Éric Ciotti',
#     'panel': '8',
#     'withdrawn': False,
#     'nb': 20161,
#     'pole_code': 'EXD',
#     'pole_party': 'À droite ! Les amis d’Éric Ciotti',
#     'party_name': 'À droite ! Les amis d’Éric Ciotti',
#     'incumbent': False,
#     'spread': {'ratio': 14.38, 'nb': 7619}},
#    {'code': 'UG',
#     'sex': 'Mme',
#     'score': 24.34,
#     'level': 'local',
#     'label': 'Florence PISANI / NFP / La France insoumise',
#     'panel': '4',
#     'withdrawn': False,
#     'nb': 12542,
#     'pole_code': 'NFP',
#     'pole_party': 'La France insoumise',
#     'party_name': 'La France insoumise',
#     'incumbent': False,
#     'spread': {'ratio': 5.46, 'nb': 2891}}]},
#  {'code': 'others',
#   'wording': 'Autres candidats',
#   'lines': [{'code': 'DVD',
#     'sex': 'M.',
#     'score': 18.73,
#     'level': 'local',
#     'label': 'Damien ABAD / Divers droite',
#     'panel': '5',
#     'withdrawn': False,
#     'nb': 9651,
#     'pole_code': '',
#     'pole_party': '',
#     'party_name': 'Divers droite',
#     'incumbent': True,
#     'spread': {'ratio': 6.82, 'nb': 3615}},
#    {'code': 'ENS',
#     'sex': 'Mme',
#     'score': 11.71,
#     'level': 'local',
#     'label': 'Nathalie DESCOURS / ENS / Renaissance',
#     'panel': '6',
#     'withdrawn': False,
#     'nb': 6036,
#     'pole_code': 'ENS',
#     'pole_party': 'Renaissance',
#     'party_name': 'Renaissance',
#     'incumbent': False,
#     'spread': {'ratio': 8.33, 'nb': 4413}},
#    {'code': 'LR',
#     'sex': 'M.',
#     'score': 3.15,
#     'level': 'local',
#     'label': 'Fabrice BOURDIN / LR / Les Républicains',
#     'panel': '3',
#     'withdrawn': False,
#     'nb': 1623,
#     'pole_code': 'LR',
#     'pole_party': 'Les Républicains',
#     'party_name': 'Les Républicains',
#     'incumbent': False,
#     'spread': {'ratio': 1.92, 'nb': 1017}},
#    {'code': 'EXG',
#     'sex': 'Mme',
#     'score': 1.18,
#     'level': 'local',
#     'label': 'Sylvie CROZET / Lutte ouvrière',
#     'panel': '2',
#     'withdrawn': False,
#     'nb': 606,
#     'pole_code': '',
#     'pole_party': '',
#     'party_name': 'Lutte ouvrière',
#     'incumbent': False,
#     'spread': {'ratio': 0.23, 'nb': 122}},
#    {'code': 'ECO',
#     'sex': 'M.',
#     'score': 0.94,
#     'level': 'local',
#     'label': 'Thomas CHATELARD / Régions et peuples solidaires',
#     'panel': '1',
#     'withdrawn': False,
#     'nb': 484,
#     'pole_code': '',
#     'pole_party': '',
#     'party_name': 'Régions et peuples solidaires',
#     'incumbent': False,
#     'spread': {'ratio': 0.1, 'nb': 55}},
#    {'code': 'REC',
#     'sex': 'Mme',
#     'score': 0.83,
#     'level': 'local',
#     'label': 'Maria Cristina PATRU / Reconquête !',
#     'panel': '7',
#     'withdrawn': False,
#     'nb': 429,
#     'pole_code': '',
#     'pole_party': '',
#     'party_name': 'Reconquête !',
#     'incumbent': False,
#     'spread': {'ratio': 0.1, 'nb': -1}}]}]

# %%
# exemple de données 'elected'
df['premier_tour'][5][1:]
# Out:
# [{'code': 'elected',
#   'wording': 'Candidat(e) élu(e)',
#   'lines': [{'code': 'RN',
#     'sex': 'M.',
#     'score': 54.49,
#     'level': 'local',
#     'label': 'Nicolas DRAGON / EXD / Rassemblement national',
#     'panel': '4',
#     'withdrawn': False,
#     'nb': 24774,
#     'pole_code': 'EXD',
#     'pole_party': 'Rassemblement national',
#     'party_name': 'Rassemblement national',
#     'incumbent': True,
#     'spread': {'ratio': 30.57, 'nb': 14394}}]},
#  {'code': 'others',
#   'wording': 'Autres candidats',
#   'lines': [{'code': 'ENS',
#     'sex': 'M.',
#     'score': 22.83,
#     'level': 'local',
#     'label': 'Damien DELAVENNE / ENS / Renaissance',
#     'panel': '6',
#     'withdrawn': False,
#     'nb': 10380,
#     'pole_code': 'ENS',
#     'pole_party': 'Renaissance',
#     'party_name': 'Renaissance',
#     'incumbent': False,
#     'spread': {'ratio': 3.67, 'nb': 1726}},
#    {'code': 'UG',
#     'sex': 'M.',
#     'score': 19.03,
#     'level': 'local',
#     'label': 'Charles CULIOLI / NFP / Parti socialiste',
#     'panel': '1',
#     'withdrawn': False,
#     'nb': 8654,
#     'pole_code': 'NFP',
#     'pole_party': 'Parti socialiste',
#     'party_name': 'Parti socialiste',
#     'incumbent': False,
#     'spread': {'ratio': 16.89, 'nb': 7953}},
#    {'code': 'EXG',
#     'sex': 'M.',
#     'score': 1.54,
#     'level': 'local',
#     'label': 'Jean-Loup PERNELLE / Lutte ouvrière',
#     'panel': '5',
#     'withdrawn': False,
#     'nb': 701,
#     'pole_code': '',
#     'pole_party': '',
#     'party_name': 'Lutte ouvrière',
#     'incumbent': False,
#     'spread': {'ratio': 0.12, 'nb': 57}},
#    {'code': 'REC',
#     'sex': 'M.',
#     'score': 1.42,
#     'level': 'local',
#     'label': 'Philippe TRÉGUIER / Reconquête !',
#     'panel': '2',
#     'withdrawn': False,
#     'nb': 644,
#     'pole_code': '',
#     'pole_party': '',
#     'party_name': 'Reconquête !',
#     'incumbent': False,
#     'spread': {'ratio': 0.7, 'nb': 328}},
#    {'code': 'DIV',
#     'sex': 'M.',
#     'score': 0.69,
#     'level': 'local',
#     'label': 'Matthieu Léon BOUFFLET / Divers',
#     'panel': '3',
#     'withdrawn': False,
#     'nb': 316,
#     'pole_code': '',
#     'pole_party': '',
#     'party_name': 'Divers',
#     'incumbent': False,
#     'spread': {'ratio': 0.7, 'nb': -1}}]}]

# %%
# extraire les données candidat 1
for i, row in df.iterrows():
    df.loc[i, 'candidat_1'] = row['premier_tour'][1]['lines'][0]['label']
    df.loc[i, 'candidat_1_parti'] = row['premier_tour'][1]['lines'][0]['pole_code']
    df.loc[i, 'candidat_1_score'] = row['premier_tour'][1]['lines'][0]['score']

# %%
# extraire les données candidat 2
for i, row in df.iterrows():
    if row['premier_tour'][1]['code'] != 'elected':
        df.loc[i, 'candidat_2'] = row['premier_tour'][1]['lines'][1]['label']
        df.loc[i, 'candidat_2_parti'] = row['premier_tour'][1]['lines'][1]['pole_code']
        df.loc[i, 'candidat_2_score'] = row['premier_tour'][1]['lines'][1]['score']

# %%
# extraire les données candidat 3
for i, row in df.iterrows():
    if (
        row['premier_tour'][1]['code'] != 'elected'
        and len(row['premier_tour'][1]['lines']) == 3
    ):
        df.loc[i, 'candidat_3'] = row['premier_tour'][1]['lines'][2]['label']
        df.loc[i, 'candidat_3_parti'] = row['premier_tour'][1]['lines'][2]['pole_code']
        df.loc[i, 'candidat_3_score'] = row['premier_tour'][1]['lines'][2]['score']

# %%
# indiquer si second tour
df['second_tour'] = df['premier_tour'].apply(
    lambda x: False if x[1]['code'] == 'elected' else True
)

# %%
# indiquer si second tour entre NFP et RN
for i, row in df.iterrows():
    df.loc[i, 'NFP_vs_RN'] = (
        row['candidat_1_parti'] in ['NFP', 'EXD'] 
        and row['candidat_2_parti'] in ['NFP', 'EXD']
)

# %%
# indiquer difference de voix et si la différence est grande
for i, row in df.iterrows():
    if row['candidat_2'] is not None:
        df.loc[i, 'diff_vote'] = row['candidat_1_score'] - row['candidat_2_score']

        diff = df.loc[i, 'diff_vote']

        if diff < 0.5:
            df.loc[i, 'swing_circo'] = '<0.5'
        elif diff < 1:
            df.loc[i, 'swing_circo'] = '<1'
        elif diff < 2:
            df.loc[i, 'swing_circo'] = '<2'
        elif diff < 5:
            df.loc[i, 'swing_circo'] = '<5'

# %%
df.head(10)
# Out:
#   code_circo                                       premier_tour  \
# 0     001-01  [{'code': 'participation', 'wording': 'Partici...
# 1     001-02  [{'code': 'participation', 'wording': 'Partici...
# 2     001-03  [{'code': 'participation', 'wording': 'Partici...
# 3     001-04  [{'code': 'participation', 'wording': 'Partici...
# 4     001-05  [{'code': 'participation', 'wording': 'Partici...
# 5     002-01  [{'code': 'participation', 'wording': 'Partici...
# 6     002-02  [{'code': 'participation', 'wording': 'Partici...
# 7     002-03  [{'code': 'participation', 'wording': 'Partici...
# 8     002-04  [{'code': 'participation', 'wording': 'Partici...
# 9     002-05  [{'code': 'participation', 'wording': 'Partici...
#
#    participation                                         candidat_1  \
# 0          71.20   Christophe MAÎTRE / EXD / Rassemblement national
# 1          72.09      Andréa KOTARAC / EXD / Rassemblement national
# 2          65.33                  Olga GIVERNET / ENS / Renaissance
# 3          70.31      Jérôme BUISSON / EXD / Rassemblement national
# 4          68.00  Marc CHAVENT / EXD / À droite ! Les amis d’Éri...
# 5          65.35      Nicolas DRAGON / EXD / Rassemblement national
# 6          63.82      Philippe TORRE / EXD / Rassemblement national
# 7          64.16      Eddy CASTERMAN / EXD / Rassemblement national
# 8          61.41       José BEAURAIN / EXD / Rassemblement national
# 9          65.34    Jocelyn DESSIGNY / EXD / Rassemblement national
#
#   candidat_1_parti  candidat_1_score  \
# 0              EXD             39.37
# 1              EXD             39.20
# 2              ENS             32.43
# 3              EXD             46.01
# 4              EXD             39.12
# 5              EXD             54.49
# 6              EXD             47.06
# 7              EXD             57.64
# 8              EXD             55.04
# 9              EXD             53.07
#
#                                       candidat_2 candidat_2_parti  \
# 0          Xavier BRETON / LR / Les Républicains               LR
# 1                    Romain DAUBIÉ / ENS / Modem              ENS
# 2  Karine DUBARRY / EXD / Rassemblement national              EXD
# 3           Christophe COQUELET / ENS / Horizons              ENS
# 4    Florence PISANI / NFP / La France insoumise              NFP
# 5                                            NaN              NaN
# 6                Julien DIVE / LR / Du courage !               LR
# 7                                            NaN              NaN
# 8                                            NaN              NaN
# 9                                            NaN              NaN
#
#    candidat_2_score                                   candidat_3  \
# 0             23.96   Sébastien GUERAUD / NFP / Parti socialiste
# 1             24.21         Maxime MEYER / NFP / Les Écologistes
# 2             32.11  Christian JOLIE / NFP / La France insoumise
# 3             21.87     Charline LIOTIER / NFP / Les Écologistes
# 4             24.34                                          NaN
# 5               NaN                                          NaN
# 6             35.66                                          NaN
# 7               NaN                                          NaN
# 8               NaN                                          NaN
# 9               NaN                                          NaN
#
#   candidat_3_parti  candidat_3_score  second_tour NFP_vs_RN  diff_vote  \
# 0              NFP             23.45         True     False      15.41
# 1              NFP             23.61         True     False      14.99
# 2              NFP             25.12         True     False       0.32
# 3              NFP             19.96         True     False      24.14
# 4              NaN               NaN         True      True      14.78
# 5              NaN               NaN        False     False        NaN
# 6              NaN               NaN         True     False      11.40
# 7              NaN               NaN        False     False        NaN
# 8              NaN               NaN        False     False        NaN
# 9              NaN               NaN        False     False        NaN
#
#   swing_circo
# 0         NaN
# 1         NaN
# 2        <0.5
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
# dropper colonne 'premier_tour'
df = df.drop(columns=['premier_tour'])

# %%
# convertir les dtypes
df = df.convert_dtypes()

df.info()

# %%
url_circos = 'https://apps.contexte.com/data/ctx-dzc/2024-06-legislatives.json'

res = requests.get(url_circos)

data_circos = res.json()

# %%
df_circos = pd.DataFrame.from_records(data_circos['districts'])[['code', 'name_full']]

df_circos.columns = ['code_circo', 'circo']

df_circos.head()
# Out:
#   code_circo    circo
# 0     001-01  Ain – 1
# 1     001-02  Ain – 2
# 2     001-03  Ain – 3
# 3     001-04  Ain – 4
# 4     001-05  Ain – 5

# %%
df = df.merge(
    right=df_circos,
    on='code_circo'
)

df.head()
# Out:
#   code_circo  second_tour swing_circo  \
# 0     001-01         True        <NA>
# 1     001-02         True        <NA>
# 2     001-03         True        <0.5
# 3     001-04         True        <NA>
# 4     001-05         True        <NA>
#
#                                           candidat_1 candidat_1_parti  \
# 0   Christophe MAÎTRE / EXD / Rassemblement national              EXD
# 1      Andréa KOTARAC / EXD / Rassemblement national              EXD
# 2                  Olga GIVERNET / ENS / Renaissance              ENS
# 3      Jérôme BUISSON / EXD / Rassemblement national              EXD
# 4  Marc CHAVENT / EXD / À droite ! Les amis d’Éri...              EXD
#
#    candidat_1_score                                     candidat_2  \
# 0             39.37          Xavier BRETON / LR / Les Républicains
# 1              39.2                    Romain DAUBIÉ / ENS / Modem
# 2             32.43  Karine DUBARRY / EXD / Rassemblement national
# 3             46.01           Christophe COQUELET / ENS / Horizons
# 4             39.12    Florence PISANI / NFP / La France insoumise
#
#   candidat_2_parti  candidat_2_score  \
# 0               LR             23.96
# 1              ENS             24.21
# 2              EXD             32.11
# 3              ENS             21.87
# 4              NFP             24.34
#
#                                     candidat_3 candidat_3_parti  \
# 0   Sébastien GUERAUD / NFP / Parti socialiste              NFP
# 1         Maxime MEYER / NFP / Les Écologistes              NFP
# 2  Christian JOLIE / NFP / La France insoumise              NFP
# 3     Charline LIOTIER / NFP / Les Écologistes              NFP
# 4                                         <NA>             <NA>
#
#    candidat_3_score  diff_vote    circo
# 0             23.45      15.41  Ain – 1
# 1             23.61      14.99  Ain – 2
# 2             25.12       0.32  Ain – 3
# 3             19.96      24.14  Ain – 4
# 4              <NA>      14.78  Ain – 5

# %%
# déplacer les colonnes
df = df.reindex(
    columns=[
        'circo',
        'code_circo',
        'second_tour',
        'swing_circo',
        'candidat_1',
        'candidat_1_parti',
        'candidat_1_score',
        'candidat_2',
        'candidat_2_parti',
        'candidat_2_score',
        'candidat_3',
        'candidat_3_parti',
        'candidat_3_score',
        'diff_vote',
    ]
)

# %% [markdown]
# ## Export data

# %%
# exporter en csv
df.to_csv('../data/resultats.csv', index=False)

# %%
# exporter en xlsx
df.to_excel('../data/resultats.xlsx')
